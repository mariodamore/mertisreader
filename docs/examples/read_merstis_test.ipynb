# %% [markdown]
# # Import Required Libraries
# Import the necessary libraries, including pathlib, re, rich, numpy, pandas, logging, and the MERTISSessionReader class.

# %%
# Import Required Libraries
import pathlib
import rich
import mertisreader as mr
import pandas as pd
# # Set up logging
# logging.basicConfig(level=logging.INFO)

# Verify the imports
print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %% [markdown]
# # Initialize MERTISSessionReader
# Initialize the MERTISSessionReader with the input directory and optional parameters for output directory and log level.

# %%
# Initialize MERTISSessionReader
input_path = pathlib.Path('../data/bcmer_tm_all_START-20200409T000000_END-20200410T000000_CRE-20240717T132010-ParamEventBootSciHK-short/cal')
output_path = pathlib.Path('/tmp/')
log_level = 'INFO'

# check if the input path exists
if not input_path.exists():
    print(f"Input path {input_path} does not exist.")
else:
    print(f"Reading path {input_path}")
# Out:
# Reading path ../data/bcmer_tm_all_START-20200409T000000_END-20200410T000000_CRE-20240717T132010-ParamEventBootSciHK-short/cal

# %%
# Initialize the MERTISDataPackReader with the input directory and optional parameters
ms_reader = mr.MERTISDataPackReader(input_dir=input_path, output_dir=output_path, log_level=log_level)

# Verify the initialization
print(f'MERTISSessionReader initialized with input directory: {ms_reader.input_dir}')
print(f'Output directory: {ms_reader.output_dir}')
print(f'Log level: {ms_reader.log_level}')
# Out:
# 2026-06-10 11:42:21,517|1297802|INFO|input_dir=PosixPath('../data/bcmer_tm_all_START-20200409T000000_END-20200410T000000_CRE-20240717T132010-ParamEventBootSciHK-short/cal')
# MERTISSessionReader initialized with input directory: ../data/bcmer_tm_all_START-20200409T000000_END-20200410T000000_CRE-20240717T132010-ParamEventBootSciHK-short/cal
# Output directory: /tmp
# Log level: INFO

# %% [markdown]
# # Show Files in Input Directory
# Use the show_files method to print statistics about the files in the input directory.

# %%
# Show Files in Input Directory
ms_reader.show_files()
# Out:
# All files in input_dir :
# Counter({'.dat': 2, '.lblx': 3, '.fits': 1})
# All files in input_dir matching old pattern <v0.2.6 (\d{8}_\d{8}):
# Counter()
# All files in input_dir matching new pattern >=v0.2.6 (mer_cal_sc_tis_YYYYMMDD_1-...):
# Counter({'mer_cal_sc_tis': 1})

# %% [markdown]
# # List File Types
# Use the listfiletypes method to print the list of file types and the number of files for each file type.

# %%
# List File Types
ms_reader.listfiletypes()
# Out:
# {
#     'hk_default': ['mer_cal_hk_default_20200409_1-0651130766-12538__0_1.dat'],
#     'hk_extended': ['mer_cal_hk_extended_20200409_1-0651130766-12595__0_1.dat'],
#     'sc_tis': ['mer_cal_sc_tis_20200409_1-0651130819-21186__0_1.fits'],
#     'sc_tir': [],
#     'sc_tis_ql': [],
#     'sc_tir_ql': []
# }
# {'hk_default': 1, 'hk_extended': 1, 'sc_tis': 1, 'sc_tir': 0, 'sc_tis_ql': 0, 'sc_tir_ql': 0}

# %% [markdown]
# # Collect Data
# Use the data_collector method to collect data from the input files and store it in the collect_data attribute.

# %%
# Collect Data
ms_reader.data_collector()

# Verify the collected data
print(f'Collected data keys: {ms_reader.collect_data.keys()}')
for key, value in ms_reader.collect_data.items():
    print(f'{key}: {len(value)} files collected')
# Out:
# Processing label: ../data/bcmer_tm_all_START-20200409T000000_END-20200410T000000_CRE-20240717T132010-ParamEventBootSciHK-short/cal/mer_cal_hk_default_20200409_1-0651130766-12538__0_1.lblx
# Now processing a Table_Delimited structure: MERTIS_CAL_DEFAULT_HOUSEKEEPING_DATA_TABLE
# Reading filetype: hk_default from mer_cal_hk_default_20200409_1-0651130766-12538__0_1
# Processing label: ../data/bcmer_tm_all_START-20200409T000000_END-20200410T000000_CRE-20240717T132010-ParamEventBootSciHK-short/cal/mer_cal_hk_extended_20200409_1-0651130766-12595__0_1.lblx
# Now processing a Table_Delimited structure: MERTIS_CAL_EXTENDED_HOUSEKEEPING_DATA_TABLE
# Reading filetype: hk_extended from mer_cal_hk_extended_20200409_1-0651130766-12595__0_1
# Reading filetype: tis from mer_cal_sc_tis_20200409_1-0651130819-21186__0_1
# Collected data keys: dict_keys(['hk_default', 'hk_extended', 'tis'])
# hk_default: 1 files collected
# hk_extended: 1 files collected
# tis: 1 files collected

# %% [markdown]
# # Assemble Data
# Use the data_assembler method to assemble the collected data into convenient data structures.

# %%
# Assemble Data
ms_reader.data_assembler(verbose=True)
# Out:
# Output()
# Reading filetype: tis from
# ../data/bcmer_tm_all_START-20200409T000000_END-20200410T000000_CRE-20240717T132010-ParamEventBootSciHK-short/cal/me
# r_cal_sc_tis_20200409_1-0651130819-21186__0_1.fits
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# n_wav=40 # generic wavelengths : not precise enough for scientific analysis!
# |    | tis_stem                                        |   finite(geo) |   geo.size |
# |---:|:------------------------------------------------|--------------:|-----------:|
# |  0 | mer_cal_sc_tis_20200409_1-0651130819-21186__0_1 |           672 |      10500 |
# Indices of measurements targets (HK_STAT_TIS_DATA_ACQ_TARGET):
# space_index_merged.shape=(21,)
# bb7_index_merged.shape=(0,)
# bb3_index_merged.shape=(0,)
# planet_index_merged.shape=(0,)
# Collected data statistics:
# Number of TIS files: 1
# Number of HK files: 2
# Number of TIR files: 0
# Number of TIS QL files: 0
# Number of TIR QL files: 0

# %%
# Verify the assembled data
if ms_reader.processing_level != "RAW":
    print(f'Geometry data keys: {ms_reader.geom_ls.keys()}')
print(f'Frames data keys: {ms_reader.frames.keys()}')
print('Shape for each file DataCube, filename is the dict key :')
rich.print({k:v.shape for k,v in ms_reader.frames.items()})
print(f'Wavelengths data keys: {ms_reader.wavelengths.keys()}')
print(f'MERTIS TIS metadata keys: {ms_reader.mertis_tis_metadata.keys()}')
print(f'Space index merged shape: {ms_reader.space_index_merged.shape}')
print(f'BB7 index merged shape: {ms_reader.bb7_index_merged.shape}')
print(f'BB3 index merged shape: {ms_reader.bb3_index_merged.shape}')
print(f'Planet index merged shape: {ms_reader.planet_index_merged.shape}')
# Out:
# Geometry data keys: dict_keys(['mer_cal_sc_tis_20200409_1-0651130819-21186__0_1'])
# Frames data keys: dict_keys(['mer_cal_sc_tis_20200409_1-0651130819-21186__0_1'])
# Shape for each file DataCube, filename is the dict key :
# {'mer_cal_sc_tis_20200409_1-0651130819-21186__0_1': (40, 100, 21)}
# Wavelengths data keys: dict_keys(['mer_cal_sc_tis_20200409_1-0651130819-21186__0_1'])
# MERTIS TIS metadata keys: dict_keys(['mer_cal_sc_tis_20200409_1-0651130819-21186__0_1'])
# Space index merged shape: (21,)
# BB7 index merged shape: (0,)
# BB3 index merged shape: (0,)
# Planet index merged shape: (0,)

# %%
file_key = list(ms_reader.frames.keys())[0]
print(f'Example DataCube shape for file {file_key}: {ms_reader.frames[file_key].shape}')
# Out:
# Example DataCube shape for file mer_cal_sc_tis_20200409_1-0651130819-21186__0_1: (40, 100, 21)

# %%
keys = [ 
 'bb3_index',
 'bb7_index',
 'planet_index',
 'space_index',
 'collect_data',
 'fits_files',
 'frames',
 'geom_ls',
 'input_dir',
 'input_path_dict',
 'log_level',
 'mertis_tis_metadata',
 'output_dir',
 'wavelengths']


# for each element in keys get attribute with samme name from ms_reader obbject and print the type of the attribute
for key in keys:
    attr = getattr(ms_reader, key)
    if isinstance(attr, dict):
        print(f'{key}: dict {len(attr.keys())} keys:')
        for k, v in attr.items():
            print(f'   {k}: {type(v)}')
    elif isinstance(attr, pathlib.Path):
        print(f'{key}: {attr}')
    elif isinstance(attr, pd.core.indexes.base.Index):
        print(f'{key}: {attr.shape}')
    elif isinstance(attr, list):
        print(f'{key}: {len(attr)}')
    elif isinstance(attr, str):
        print(f'{key}: {attr}')
    else:
        print(f'UNCAUGHT {key}: {type(attr)}')
# Out:
# bb3_index: dict 1 keys:
#    mer_cal_sc_tis_20200409_1-0651130819-21186__0_1: <class 'pandas.core.indexes.base.Index'>
# bb7_index: dict 1 keys:
#    mer_cal_sc_tis_20200409_1-0651130819-21186__0_1: <class 'pandas.core.indexes.base.Index'>
# planet_index: dict 1 keys:
#    mer_cal_sc_tis_20200409_1-0651130819-21186__0_1: <class 'pandas.core.indexes.base.Index'>
# space_index: dict 1 keys:
#    mer_cal_sc_tis_20200409_1-0651130819-21186__0_1: <class 'pandas.core.indexes.range.RangeIndex'>
# collect_data: dict 3 keys:
#    hk_default: <class 'list'>
#    hk_extended: <class 'list'>
#    tis: <class 'list'>
# fits_files: 3
# frames: dict 1 keys:
#    mer_cal_sc_tis_20200409_1-0651130819-21186__0_1: <class 'numpy.ndarray'>
# geom_ls: dict 1 keys:
#    mer_cal_sc_tis_20200409_1-0651130819-21186__0_1: <class 'dict'>
# input_dir: ../data/bcmer_tm_all_START-20200409T000000_END-20200410T000000_CRE-20240717T132010-ParamEventBootSciHK-short/cal
# input_path_dict: dict 6 keys:
#    hk_default: <class 'list'>
#    hk_extended: <class 'list'>
#    sc_tis: <class 'list'>
#    sc_tir: <class 'list'>
#    sc_tis_ql: <class 'list'>
#    sc_tir_ql: <class 'list'>
# log_level: INFO
# mertis_tis_metadata: dict 1 keys:
#    mer_cal_sc_tis_20200409_1-0651130819-21186__0_1: <class 'pandas.core.frame.DataFrame'>
# output_dir: /tmp
# wavelengths: dict 1 keys:
#    mer_cal_sc_tis_20200409_1-0651130819-21186__0_1: <class 'numpy.ndarray'>

# %%
ms_reader.mertis_tis_metadata[file_key]
# Out:
#                     TIME_UTC            TIME_OBT     TimeStamp  \
# 0   2020-04-09T05:40:20.710Z  1/0651130819:21186  6.511308e+08
# 1   2020-04-09T05:40:31.748Z  1/0651130830:23689  6.511308e+08
# 2   2020-04-09T05:40:32.548Z  1/0651130831:10567  6.511308e+08
# 3   2020-04-09T05:40:33.348Z  1/0651130831:62998  6.511308e+08
# 4   2020-04-09T05:40:34.148Z  1/0651130832:49891  6.511308e+08
# 5   2020-04-09T05:40:34.948Z  1/0651130833:36784  6.511308e+08
# 6   2020-04-09T05:40:35.748Z  1/0651130834:23676  6.511308e+08
# 7   2020-04-09T05:40:36.548Z  1/0651130835:10569  6.511308e+08
# 8   2020-04-09T05:40:37.348Z  1/0651130835:62998  6.511308e+08
# 9   2020-04-09T05:40:38.148Z  1/0651130836:49891  6.511308e+08
# 10  2020-04-09T05:40:38.948Z  1/0651130837:36783  6.511308e+08
# 11  2020-04-09T05:40:39.748Z  1/0651130838:23676  6.511308e+08
# 12  2020-04-09T05:40:40.548Z  1/0651130839:10569  6.511308e+08
# 13  2020-04-09T05:40:41.348Z  1/0651130839:62998  6.511308e+08
# 14  2020-04-09T05:40:42.148Z  1/0651130840:49891  6.511308e+08
# 15  2020-04-09T05:40:42.948Z  1/0651130841:36783  6.511308e+08
# 16  2020-04-09T05:40:43.748Z  1/0651130842:23676  6.511308e+08
# 17  2020-04-09T05:40:44.548Z  1/0651130843:10569  6.511308e+08
# 18  2020-04-09T05:40:45.348Z  1/0651130843:62998  6.511308e+08
# 19  2020-04-09T05:40:46.148Z  1/0651130844:49891  6.511308e+08
# 20  2020-04-09T05:40:46.948Z  1/0651130845:36784  6.511308e+08
#
#     HK_STAT_TIS_DATA_ACQ_ID HK_STAT_TIS_DATA_ACQ_TYPE  \
# 0                      3740                   Sci_Raw
# 1                      3743        Sci_Subtracted_BB3
# 2                      3744        Sci_Subtracted_BB3
# 3                      3745        Sci_Subtracted_BB3
# 4                      3746        Sci_Subtracted_BB3
# 5                      3747        Sci_Subtracted_BB3
# 6                      3748        Sci_Subtracted_BB3
# 7                      3749        Sci_Subtracted_BB3
# 8                      3750        Sci_Subtracted_BB3
# 9                      3751        Sci_Subtracted_BB3
# 10                     3752        Sci_Subtracted_BB3
# 11                     3753        Sci_Subtracted_BB3
# 12                     3754        Sci_Subtracted_BB3
# 13                     3755        Sci_Subtracted_BB3
# 14                     3756        Sci_Subtracted_BB3
# 15                     3757        Sci_Subtracted_BB3
# 16                     3758        Sci_Subtracted_BB3
# 17                     3759        Sci_Subtracted_BB3
# 18                     3760        Sci_Subtracted_BB3
# 19                     3761        Sci_Subtracted_BB3
# 20                     3762                   Sci_Raw
#
#    HK_STAT_TIS_DATA_ACQ_TARGET  HK_STAT_BOL_BIAS_VOLT_ACTIVE_PARAM_SET  \
# 0                        Space                                       2
# 1                        Space                                       2
# 2                        Space                                       2
# 3                        Space                                       2
# 4                        Space                                       2
# 5                        Space                                       2
# 6                        Space                                       2
# 7                        Space                                       2
# 8                        Space                                       2
# 9                        Space                                       2
# 10                       Space                                       2
# 11                       Space                                       2
# 12                       Space                                       2
# 13                       Space                                       2
# 14                       Space                                       2
# 15                       Space                                       2
# 16                       Space                                       2
# 17                       Space                                       2
# 18                       Space                                       2
# 19                       Space                                       2
# 20                       Space                                       2
#
#     HK_STAT_TIS_DATA_ACQ_TIME PAR_TIS_BIN_MODE PAR_TIS_WIN_SIZE  ...  \
# 0                6.511308e+08              1x2      100x80pixel  ...
# 1                6.511308e+08              1x2      100x80pixel  ...
# 2                6.511308e+08              1x2      100x80pixel  ...
# 3                6.511308e+08              1x2      100x80pixel  ...
# 4                6.511308e+08              1x2      100x80pixel  ...
# 5                6.511308e+08              1x2      100x80pixel  ...
# 6                6.511308e+08              1x2      100x80pixel  ...
# 7                6.511308e+08              1x2      100x80pixel  ...
# 8                6.511308e+08              1x2      100x80pixel  ...
# 9                6.511308e+08              1x2      100x80pixel  ...
# 10               6.511308e+08              1x2      100x80pixel  ...
# 11               6.511308e+08              1x2      100x80pixel  ...
# 12               6.511308e+08              1x2      100x80pixel  ...
# 13               6.511308e+08              1x2      100x80pixel  ...
# 14               6.511308e+08              1x2      100x80pixel  ...
# 15               6.511308e+08              1x2      100x80pixel  ...
# 16               6.511308e+08              1x2      100x80pixel  ...
# 17               6.511308e+08              1x2      100x80pixel  ...
# 18               6.511308e+08              1x2      100x80pixel  ...
# 19               6.511308e+08              1x2      100x80pixel  ...
# 20               6.511308e+08              1x2      100x80pixel  ...
#
#    HK_STAT_TIS_COMP_NUM_BANDS  HK_STAT_TIS_NUM_OVERSAMP  HK_TEMP_BOL_CHIP  \
# 0                           5                         0            15.000
# 1                           5                        32            15.000
# 2                           5                        32            15.003
# 3                           5                        32            15.002
# 4                           5                        32            15.001
# 5                           5                        32            15.002
# 6                           5                        32            15.001
# 7                           5                        32            15.002
# 8                           5                        32            15.001
# 9                           5                        32            15.000
# 10                          5                        32            14.999
# 11                          5                        32            15.000
# 12                          5                        32            15.000
# 13                          5                        32            15.001
# 14                          5                        32            15.000
# 15                          5                        32            15.000
# 16                          5                        32            15.000
# 17                          5                        32            14.998
# 18                          5                        32            15.001
# 19                          5                        32            14.997
# 20                          5                         0            14.999
#
#     DAT_TIS_OFFSET_MACRO_PIXEL  HK_TEMP_BOL_HOUSING  HK_TEMP_OST_BASE_PLATE  \
# 0                            1                9.527                   9.894
# 1                         2052                9.519                   9.891
# 2                         2052                9.519                   9.889
# 3                         2053                9.520                   9.889
# 4                         2054                9.520                   9.888
# 5                         2055                9.519                   9.888
# 6                         2055                9.519                   9.888
# 7                         2056                9.520                   9.889
# 8                         2057                9.520                   9.889
# 9                         2057                9.521                   9.889
# 10                        2058                9.520                   9.888
# 11                        2058                9.520                   9.889
# 12                        2059                9.522                   9.889
# 13                        2059                9.522                   9.888
# 14                        2060                9.522                   9.888
# 15                        2060                9.523                   9.888
# 16                        2061                9.523                   9.888
# 17                        2061                9.524                   9.888
# 18                        2062                9.524                   9.888
# 19                        2062                9.525                   9.888
# 20                           1                9.526                   9.888
#
#     PAR_TIS_DATA_NOISE_REDUCTION  HK_STAT_TIS_TOTAL_PACKET_NUM  \
# 0                              0                             1
# 1                              0                             1
# 2                              0                             1
# 3                              0                             1
# 4                              0                             1
# 5                              0                             1
# 6                              0                             1
# 7                              0                             1
# 8                              0                             1
# 9                              0                             1
# 10                             0                             1
# 11                             0                             1
# 12                             0                             1
# 13                             0                             1
# 14                             0                             1
# 15                             0                             1
# 16                             0                             1
# 17                             0                             1
# 18                             0                             1
# 19                             0                             1
# 20                             0                             1
#
#     HK_STAT_TIS_CURRENT_PACKET_NUM  HK_STAT_TIS_NUM_DATA_WORDS
# 0                                1                         384
# 1                                1                        1206
# 2                                1                        1200
# 3                                1                        1208
# 4                                1                        1192
# 5                                1                        1194
# 6                                1                        1204
# 7                                1                        1196
# 8                                1                        1218
# 9                                1                        1200
# 10                               1                        1208
# 11                               1                        1218
# 12                               1                        1214
# 13                               1                        1228
# 14                               1                        1216
# 15                               1                        1214
# 16                               1                        1216
# 17                               1                        1218
# 18                               1                        1218
# 19                               1                        1218
# 20                               1                         384
#
# [21 rows x 24 columns]

# %% [markdown]
# # Plots

# %%
import matplotlib
import matplotlib.dates as mdates
from matplotlib import pyplot as plt
from IPython.display import display

# %%
ms_reader.mertis_tis_metadata[file_key].iloc[0:10].T
# Out:
#                                                                0  \
# TIME_UTC                                2020-04-09T05:40:20.710Z
# TIME_OBT                                      1/0651130819:21186
# TimeStamp                                       651130823.044403
# HK_STAT_TIS_DATA_ACQ_ID                                     3740
# HK_STAT_TIS_DATA_ACQ_TYPE                                Sci_Raw
# HK_STAT_TIS_DATA_ACQ_TARGET                                Space
# HK_STAT_BOL_BIAS_VOLT_ACTIVE_PARAM_SET                         2
# HK_STAT_TIS_DATA_ACQ_TIME                       651130819.323273
# PAR_TIS_BIN_MODE                                             1x2
# PAR_TIS_WIN_SIZE                                     100x80pixel
# PAR_TIS_COMP_MODE                                       lossless
# HK_STAT_TIS_COMP_VERSION                                       1
# HK_STAT_TIS_COMP_RICE_K_VALUE                                  8
# HK_STAT_TIS_COMP_INPUT_LENGTH                                100
# HK_STAT_TIS_COMP_NUM_BANDS                                     5
# HK_STAT_TIS_NUM_OVERSAMP                                       0
# HK_TEMP_BOL_CHIP                                            15.0
# DAT_TIS_OFFSET_MACRO_PIXEL                                     1
# HK_TEMP_BOL_HOUSING                                        9.527
# HK_TEMP_OST_BASE_PLATE                                     9.894
# PAR_TIS_DATA_NOISE_REDUCTION                                   0
# HK_STAT_TIS_TOTAL_PACKET_NUM                                   1
# HK_STAT_TIS_CURRENT_PACKET_NUM                                 1
# HK_STAT_TIS_NUM_DATA_WORDS                                   384
#
#                                                                1  \
# TIME_UTC                                2020-04-09T05:40:31.748Z
# TIME_OBT                                      1/0651130830:23689
# TimeStamp                                       651130830.950928
# HK_STAT_TIS_DATA_ACQ_ID                                     3743
# HK_STAT_TIS_DATA_ACQ_TYPE                     Sci_Subtracted_BB3
# HK_STAT_TIS_DATA_ACQ_TARGET                                Space
# HK_STAT_BOL_BIAS_VOLT_ACTIVE_PARAM_SET                         2
# HK_STAT_TIS_DATA_ACQ_TIME                       651130830.361465
# PAR_TIS_BIN_MODE                                             1x2
# PAR_TIS_WIN_SIZE                                     100x80pixel
# PAR_TIS_COMP_MODE                                       lossless
# HK_STAT_TIS_COMP_VERSION                                       1
# HK_STAT_TIS_COMP_RICE_K_VALUE                                  8
# HK_STAT_TIS_COMP_INPUT_LENGTH                                100
# HK_STAT_TIS_COMP_NUM_BANDS                                     5
# HK_STAT_TIS_NUM_OVERSAMP                                      32
# HK_TEMP_BOL_CHIP                                            15.0
# DAT_TIS_OFFSET_MACRO_PIXEL                                  2052
# HK_TEMP_BOL_HOUSING                                        9.519
# HK_TEMP_OST_BASE_PLATE                                     9.891
# PAR_TIS_DATA_NOISE_REDUCTION                                   0
# HK_STAT_TIS_TOTAL_PACKET_NUM                                   1
# HK_STAT_TIS_CURRENT_PACKET_NUM                                 1
# HK_STAT_TIS_NUM_DATA_WORDS                                  1206
#
#                                                                2  \
# TIME_UTC                                2020-04-09T05:40:32.548Z
# TIME_OBT                                      1/0651130831:10567
# TimeStamp                                       651130831.746674
# HK_STAT_TIS_DATA_ACQ_ID                                     3744
# HK_STAT_TIS_DATA_ACQ_TYPE                     Sci_Subtracted_BB3
# HK_STAT_TIS_DATA_ACQ_TARGET                                Space
# HK_STAT_BOL_BIAS_VOLT_ACTIVE_PARAM_SET                         2
# HK_STAT_TIS_DATA_ACQ_TIME                        651130831.16124
# PAR_TIS_BIN_MODE                                             1x2
# PAR_TIS_WIN_SIZE                                     100x80pixel
# PAR_TIS_COMP_MODE                                       lossless
# HK_STAT_TIS_COMP_VERSION                                       1
# HK_STAT_TIS_COMP_RICE_K_VALUE                                  8
# HK_STAT_TIS_COMP_INPUT_LENGTH                                100
# HK_STAT_TIS_COMP_NUM_BANDS                                     5
# HK_STAT_TIS_NUM_OVERSAMP                                      32
# HK_TEMP_BOL_CHIP                                          15.003
# DAT_TIS_OFFSET_MACRO_PIXEL                                  2052
# HK_TEMP_BOL_HOUSING                                        9.519
# HK_TEMP_OST_BASE_PLATE                                     9.889
# PAR_TIS_DATA_NOISE_REDUCTION                                   0
# HK_STAT_TIS_TOTAL_PACKET_NUM                                   1
# HK_STAT_TIS_CURRENT_PACKET_NUM                                 1
# HK_STAT_TIS_NUM_DATA_WORDS                                  1200
#
#                                                                3  \
# TIME_UTC                                2020-04-09T05:40:33.348Z
# TIME_OBT                                      1/0651130831:62998
# TimeStamp                                       651130832.544235
# HK_STAT_TIS_DATA_ACQ_ID                                     3745
# HK_STAT_TIS_DATA_ACQ_TYPE                     Sci_Subtracted_BB3
# HK_STAT_TIS_DATA_ACQ_TARGET                                Space
# HK_STAT_BOL_BIAS_VOLT_ACTIVE_PARAM_SET                         2
# HK_STAT_TIS_DATA_ACQ_TIME                       651130831.961273
# PAR_TIS_BIN_MODE                                             1x2
# PAR_TIS_WIN_SIZE                                     100x80pixel
# PAR_TIS_COMP_MODE                                       lossless
# HK_STAT_TIS_COMP_VERSION                                       1
# HK_STAT_TIS_COMP_RICE_K_VALUE                                  8
# HK_STAT_TIS_COMP_INPUT_LENGTH                                100
# HK_STAT_TIS_COMP_NUM_BANDS                                     5
# HK_STAT_TIS_NUM_OVERSAMP                                      32
# HK_TEMP_BOL_CHIP                                          15.002
# DAT_TIS_OFFSET_MACRO_PIXEL                                  2053
# HK_TEMP_BOL_HOUSING                                         9.52
# HK_TEMP_OST_BASE_PLATE                                     9.889
# PAR_TIS_DATA_NOISE_REDUCTION                                   0
# HK_STAT_TIS_TOTAL_PACKET_NUM                                   1
# HK_STAT_TIS_CURRENT_PACKET_NUM                                 1
# HK_STAT_TIS_NUM_DATA_WORDS                                  1208
#
#                                                                4  \
# TIME_UTC                                2020-04-09T05:40:34.148Z
# TIME_OBT                                      1/0651130832:49891
# TimeStamp                                       651130833.341141
# HK_STAT_TIS_DATA_ACQ_ID                                     3746
# HK_STAT_TIS_DATA_ACQ_TYPE                     Sci_Subtracted_BB3
# HK_STAT_TIS_DATA_ACQ_TARGET                                Space
# HK_STAT_BOL_BIAS_VOLT_ACTIVE_PARAM_SET                         2
# HK_STAT_TIS_DATA_ACQ_TIME                       651130832.761276
# PAR_TIS_BIN_MODE                                             1x2
# PAR_TIS_WIN_SIZE                                     100x80pixel
# PAR_TIS_COMP_MODE                                       lossless
# HK_STAT_TIS_COMP_VERSION                                       1
# HK_STAT_TIS_COMP_RICE_K_VALUE                                  8
# HK_STAT_TIS_COMP_INPUT_LENGTH                                100
# HK_STAT_TIS_COMP_NUM_BANDS                                     5
# HK_STAT_TIS_NUM_OVERSAMP                                      32
# HK_TEMP_BOL_CHIP                                          15.001
# DAT_TIS_OFFSET_MACRO_PIXEL                                  2054
# HK_TEMP_BOL_HOUSING                                         9.52
# HK_TEMP_OST_BASE_PLATE                                     9.888
# PAR_TIS_DATA_NOISE_REDUCTION                                   0
# HK_STAT_TIS_TOTAL_PACKET_NUM                                   1
# HK_STAT_TIS_CURRENT_PACKET_NUM                                 1
# HK_STAT_TIS_NUM_DATA_WORDS                                  1192
#
#                                                                5  \
# TIME_UTC                                2020-04-09T05:40:34.948Z
# TIME_OBT                                      1/0651130833:36784
# TimeStamp                                       651130834.138077
# HK_STAT_TIS_DATA_ACQ_ID                                     3747
# HK_STAT_TIS_DATA_ACQ_TYPE                     Sci_Subtracted_BB3
# HK_STAT_TIS_DATA_ACQ_TARGET                                Space
# HK_STAT_BOL_BIAS_VOLT_ACTIVE_PARAM_SET                         2
# HK_STAT_TIS_DATA_ACQ_TIME                       651130833.561279
# PAR_TIS_BIN_MODE                                             1x2
# PAR_TIS_WIN_SIZE                                     100x80pixel
# PAR_TIS_COMP_MODE                                       lossless
# HK_STAT_TIS_COMP_VERSION                                       1
# HK_STAT_TIS_COMP_RICE_K_VALUE                                  8
# HK_STAT_TIS_COMP_INPUT_LENGTH                                100
# HK_STAT_TIS_COMP_NUM_BANDS                                     5
# HK_STAT_TIS_NUM_OVERSAMP                                      32
# HK_TEMP_BOL_CHIP                                          15.002
# DAT_TIS_OFFSET_MACRO_PIXEL                                  2055
# HK_TEMP_BOL_HOUSING                                        9.519
# HK_TEMP_OST_BASE_PLATE                                     9.888
# PAR_TIS_DATA_NOISE_REDUCTION                                   0
# HK_STAT_TIS_TOTAL_PACKET_NUM                                   1
# HK_STAT_TIS_CURRENT_PACKET_NUM                                 1
# HK_STAT_TIS_NUM_DATA_WORDS                                  1194
#
#                                                                6  \
# TIME_UTC                                2020-04-09T05:40:35.748Z
# TIME_OBT                                      1/0651130834:23676
# TimeStamp                                       651130834.952408
# HK_STAT_TIS_DATA_ACQ_ID                                     3748
# HK_STAT_TIS_DATA_ACQ_TYPE                     Sci_Subtracted_BB3
# HK_STAT_TIS_DATA_ACQ_TARGET                                Space
# HK_STAT_BOL_BIAS_VOLT_ACTIVE_PARAM_SET                         2
# HK_STAT_TIS_DATA_ACQ_TIME                       651130834.361267
# PAR_TIS_BIN_MODE                                             1x2
# PAR_TIS_WIN_SIZE                                     100x80pixel
# PAR_TIS_COMP_MODE                                       lossless
# HK_STAT_TIS_COMP_VERSION                                       1
# HK_STAT_TIS_COMP_RICE_K_VALUE                                  8
# HK_STAT_TIS_COMP_INPUT_LENGTH                                100
# HK_STAT_TIS_COMP_NUM_BANDS                                     5
# HK_STAT_TIS_NUM_OVERSAMP                                      32
# HK_TEMP_BOL_CHIP                                          15.001
# DAT_TIS_OFFSET_MACRO_PIXEL                                  2055
# HK_TEMP_BOL_HOUSING                                        9.519
# HK_TEMP_OST_BASE_PLATE                                     9.888
# PAR_TIS_DATA_NOISE_REDUCTION                                   0
# HK_STAT_TIS_TOTAL_PACKET_NUM                                   1
# HK_STAT_TIS_CURRENT_PACKET_NUM                                 1
# HK_STAT_TIS_NUM_DATA_WORDS                                  1204
#
#                                                                7  \
# TIME_UTC                                2020-04-09T05:40:36.548Z
# TIME_OBT                                      1/0651130835:10569
# TimeStamp                                       651130835.749695
# HK_STAT_TIS_DATA_ACQ_ID                                     3749
# HK_STAT_TIS_DATA_ACQ_TYPE                     Sci_Subtracted_BB3
# HK_STAT_TIS_DATA_ACQ_TARGET                                Space
# HK_STAT_BOL_BIAS_VOLT_ACTIVE_PARAM_SET                         2
# HK_STAT_TIS_DATA_ACQ_TIME                        651130835.16127
# PAR_TIS_BIN_MODE                                             1x2
# PAR_TIS_WIN_SIZE                                     100x80pixel
# PAR_TIS_COMP_MODE                                       lossless
# HK_STAT_TIS_COMP_VERSION                                       1
# HK_STAT_TIS_COMP_RICE_K_VALUE                                  8
# HK_STAT_TIS_COMP_INPUT_LENGTH                                100
# HK_STAT_TIS_COMP_NUM_BANDS                                     5
# HK_STAT_TIS_NUM_OVERSAMP                                      32
# HK_TEMP_BOL_CHIP                                          15.002
# DAT_TIS_OFFSET_MACRO_PIXEL                                  2056
# HK_TEMP_BOL_HOUSING                                         9.52
# HK_TEMP_OST_BASE_PLATE                                     9.889
# PAR_TIS_DATA_NOISE_REDUCTION                                   0
# HK_STAT_TIS_TOTAL_PACKET_NUM                                   1
# HK_STAT_TIS_CURRENT_PACKET_NUM                                 1
# HK_STAT_TIS_NUM_DATA_WORDS                                  1196
#
#                                                                8  \
# TIME_UTC                                2020-04-09T05:40:37.348Z
# TIME_OBT                                      1/0651130835:62998
# TimeStamp                                       651130836.547485
# HK_STAT_TIS_DATA_ACQ_ID                                     3750
# HK_STAT_TIS_DATA_ACQ_TYPE                     Sci_Subtracted_BB3
# HK_STAT_TIS_DATA_ACQ_TARGET                                Space
# HK_STAT_BOL_BIAS_VOLT_ACTIVE_PARAM_SET                         2
# HK_STAT_TIS_DATA_ACQ_TIME                       651130835.961273
# PAR_TIS_BIN_MODE                                             1x2
# PAR_TIS_WIN_SIZE                                     100x80pixel
# PAR_TIS_COMP_MODE                                       lossless
# HK_STAT_TIS_COMP_VERSION                                       1
# HK_STAT_TIS_COMP_RICE_K_VALUE                                  8
# HK_STAT_TIS_COMP_INPUT_LENGTH                                100
# HK_STAT_TIS_COMP_NUM_BANDS                                     5
# HK_STAT_TIS_NUM_OVERSAMP                                      32
# HK_TEMP_BOL_CHIP                                          15.001
# DAT_TIS_OFFSET_MACRO_PIXEL                                  2057
# HK_TEMP_BOL_HOUSING                                         9.52
# HK_TEMP_OST_BASE_PLATE                                     9.889
# PAR_TIS_DATA_NOISE_REDUCTION                                   0
# HK_STAT_TIS_TOTAL_PACKET_NUM                                   1
# HK_STAT_TIS_CURRENT_PACKET_NUM                                 1
# HK_STAT_TIS_NUM_DATA_WORDS                                  1218
#
#                                                                9
# TIME_UTC                                2020-04-09T05:40:38.148Z
# TIME_OBT                                      1/0651130836:49891
# TimeStamp                                       651130837.344376
# HK_STAT_TIS_DATA_ACQ_ID                                     3751
# HK_STAT_TIS_DATA_ACQ_TYPE                     Sci_Subtracted_BB3
# HK_STAT_TIS_DATA_ACQ_TARGET                                Space
# HK_STAT_BOL_BIAS_VOLT_ACTIVE_PARAM_SET                         2
# HK_STAT_TIS_DATA_ACQ_TIME                       651130836.761276
# PAR_TIS_BIN_MODE                                             1x2
# PAR_TIS_WIN_SIZE                                     100x80pixel
# PAR_TIS_COMP_MODE                                       lossless
# HK_STAT_TIS_COMP_VERSION                                       1
# HK_STAT_TIS_COMP_RICE_K_VALUE                                  8
# HK_STAT_TIS_COMP_INPUT_LENGTH                                100
# HK_STAT_TIS_COMP_NUM_BANDS                                     5
# HK_STAT_TIS_NUM_OVERSAMP                                      32
# HK_TEMP_BOL_CHIP                                            15.0
# DAT_TIS_OFFSET_MACRO_PIXEL                                  2057
# HK_TEMP_BOL_HOUSING                                        9.521
# HK_TEMP_OST_BASE_PLATE                                     9.889
# PAR_TIS_DATA_NOISE_REDUCTION                                   0
# HK_STAT_TIS_TOTAL_PACKET_NUM                                   1
# HK_STAT_TIS_CURRENT_PACKET_NUM                                 1
# HK_STAT_TIS_NUM_DATA_WORDS                                  1200

# %%
ms_reader.mertis_tis_metadata[file_key]\
    .set_index('TIME_UTC').loc[:,'HK_STAT_TIS_COMP_VERSION':]\
        .plot(figsize=[15,15], legend=True, title='MERTIS TIS Metadata', grid=True, subplots=True)

plt.tight_layout()

# %%
ms_reader.wavelengths[file_key].shape, ms_reader.frames[file_key].shape
# Out:
# ((40, 100), (40, 100, 21))

# %%
full_frames_3D = ms_reader.frames[file_key]
wav = ms_reader.wavelengths[file_key]
plot_index = ms_reader.space_index[file_key]
print(f'plot_index: {plot_index}')

fig, ax = plt.subplots(ncols=2,nrows=2, figsize = [22,12])

fig.suptitle(f'MERTIS TIS DataCube - {file_key} \n'
             f'average over the measurements {full_frames_3D.shape} -> {full_frames_3D[:,:,0].shape}',
             fontsize=16)
title = 'Space'
ax[0][0].plot(wav,full_frames_3D[:,:,plot_index].mean(axis=2));
ax[0][0].set_title(f'{title} - frames average ')
ax[0][1].imshow(full_frames_3D[:,:,plot_index].mean(axis=2),aspect='auto',cmap=plt.cm.Spectral_r)
ax[0][1].set_title(f'{title} - frames average')

ax[1][0].set_title(f'{title} - frames std')
ax[1][0].plot(wav,full_frames_3D[:,:,plot_index].std(axis=2));
ax[1][1].set_title(f'{title} - frames std')
ax[1][1].imshow(full_frames_3D[:,:,plot_index].std(axis=2),aspect='auto',cmap=plt.cm.Spectral_r)

_ = [a.set_xlabel('Wavelength [nm]') for a in ax[:,0]]
_ = [a.set_ylabel('Radiance [W/m2/sr/nm]') for a in ax[:,0]]
_ = [a.grid(True) for a in ax[:,0]]

_ = [a.set_xlabel('Frame Index') for a in ax[:,1]]
_ = [a.set_ylabel('Wavelength Index') for a in ax[:,1]]

plt.tight_layout()
# Out:
# plot_index: RangeIndex(start=0, stop=21, step=1)
